# %% [markdown]
# Your task is to:
# 1. Choose one of the New York Times APIs
# 2. Construct an interface in Python to read in the JSON data
# 3. Transform it into a pandas DataFrame
#
# I chose the Most Viewed Opinion articles in the last 30 days from the Most Popular API

# %%
import pandas as pd
import json
import urllib.request
from pandas.io.json import json_normalize

api_key = '089beac3eb674ecfb1a42ecb5cb7358c'
url = 'https://api.nytimes.com/svc/mostpopular/v2/mostviewed/Opinion/30.json?limit=100'
string = url+'&api-key='+api_key

response = str(urllib.request.urlopen(string).read(), 'utf-8')

df = pd.read_json(response)
df
# Out:
#                                             copyright  num_results  \
# 0   Copyright (c) 2017 The New York Times Company....          274
# 1   Copyright (c) 2017 The New York Times Company....          274
# 2   Copyright (c) 2017 The New York Times Company....          274
# 3   Copyright (c) 2017 The New York Times Company....          274
# 4   Copyright (c) 2017 The New York Times Company....          274
# 5   Copyright (c) 2017 The New York Times Company....          274
# 6   Copyright (c) 2017 The New York Times Company....          274
# 7   Copyright (c) 2017 The New York Times Company....          274
# 8   Copyright (c) 2017 The New York Times Company....          274
# 9   Copyright (c) 2017 The New York Times Company....          274
# 10  Copyright (c) 2017 The New York Times Company....          274
# 11  Copyright (c) 2017 The New York Times Company....          274
# 12  Copyright (c) 2017 The New York Times Company....          274
# ...

# %% [markdown]
# It looks like all the real data is in the 'results' column. So I'll load that into it's own dataframe.

# %%
data = json.loads(response)
most_viewed = json_normalize(data['results'])
most_viewed
# Out:
#                                              abstract  \
# 0   Dear President Trump: Are we going to lose so ...
# 1   We are now experiencing the very thing Team Tr...
# 2   Understanding how she got swept up in evil has...
# 3         Sounds like investment, smells like ripoff.
# 4   What if the Trump administration runs out of e...
# 5   We use them to try to “get to know” people. It...
# 6   A parable considers the Republican “health car...
# 7                   Welcome to Trump&#8217;s America.
# 8                   Chewing over the cultural divide.
# 9                Everything is an insult, apparently.
# 10  Statistics don&#8217;t win elections. Does tha...
# 11  People who have depended on programs that woul...
# 12          The untruths about Russia are escalating.
# 13  On college applications, every so often, the k...
# 14  The president my fellow believers elected is a...
# 15  New research indicates a stall, maybe even a r...
# ...
