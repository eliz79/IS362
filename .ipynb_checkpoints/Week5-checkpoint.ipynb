# %% [markdown]
# # Finding the most northern and eastern airports in the US
# ### First I'll load the .csv files and take a look

# %%
import pandas as pd

airports = pd.read_csv('/Users/Maureen/Desktop/flightsdata/airports.csv')
weather = pd.read_csv('/Users/Maureen/Desktop/flightsdata/weather.csv')

# %%
airports.head()
# Out:
#    faa                           name        lat        lon   alt   tz dst  \
# 0  04G              Lansdowne Airport  41.130472 -80.619583  1044 -5.0   A
# 1  06A  Moton Field Municipal Airport  32.460572 -85.680028   264 -6.0   A
# 2  06C            Schaumburg Regional  41.989341 -88.101243   801 -6.0   A
# 3  06N                Randall Airport  41.431912 -74.391561   523 -5.0   A
# 4  09J          Jekyll Island Airport  31.074472 -81.427778    11 -5.0   A
#
#               tzone
# 0  America/New_York
# 1   America/Chicago
# 2   America/Chicago
# 3  America/New_York
# 4  America/New_York

# %%
weather.head()
# Out:
#   origin  year  month  day  hour   temp   dewp  humid  wind_dir  wind_speed  \
# 0    EWR  2013      1    1     0  37.04  21.92  53.97     230.0    10.35702
# 1    EWR  2013      1    1     1  37.04  21.92  53.97     230.0    13.80936
# 2    EWR  2013      1    1     2  37.94  21.92  52.09     230.0    12.65858
# 3    EWR  2013      1    1     3  37.94  23.00  54.51     230.0    13.80936
# 4    EWR  2013      1    1     4  37.94  24.08  57.04     240.0    14.96014
#
#    wind_gust  precip  pressure  visib             time_hour
# 0  11.918651     0.0    1013.9   10.0  2013-01-01T00:00:00Z
# 1  15.891535     0.0    1013.0   10.0  2013-01-01T01:00:00Z
# 2  14.567241     0.0    1012.6   10.0  2013-01-01T02:00:00Z
# 3  15.891535     0.0    1012.7   10.0  2013-01-01T03:00:00Z
# 4  17.215830     0.0    1012.8   10.0  2013-01-01T04:00:00Z

# %% [markdown]
# ### I want to make sure all the airports in the list are in the United States

# %%
airports.tzone.value_counts()
# Out:
# America/New_York       519
# America/Chicago        342
# America/Anchorage      239
# America/Los_Angeles    176
# America/Denver         119
# America/Phoenix         38
# Pacific/Honolulu        18
# \N                       3
# Asia/Chongqing           2
# America/Vancouver        2
# Name: tzone, dtype: int64

# %% [markdown]
# ### It looks like they are not all in the US. I want to exclude rows based on whether the lat/lon is in the US.
# This website lists the most extreme coordinates in the US. http://www.cohp.org/extremes/extreme_points.html
# I used this information to set the lat/lon min/max to filter out non-US airports.
#
# ## Filter and find the most eastern airport

# %%
coordinates_lon = [-172.44, -66.94975]
airports = airports[(airports.lon >= coordinates_lon[0]) & (airports.lon <= coordinates_lon[1])]
east_sort = airports.sort_values('lon', ascending=False)
east_sort.iloc[0]
# Out:
# faa                             EPM
# name     Eastport Municipal Airport
# lat                         44.9101
# lon                        -67.0127
# alt                              45
# tz                               -5
# dst                               A
# tzone              America/New_York
# Name: 444, dtype: object

# %% [markdown]
# ## Filter and find the most northern airport

# %%
coordinates_lat = [18.91, 71.39]
airports = airports[(airports.lat >= coordinates_lat[0]) & (airports.lat <= coordinates_lat[1])]
north_sort = airports.sort_values('lat', ascending=False)
north_sort.iloc[0]
# Out:
# faa                             BRW
# name     Wiley Post Will Rogers Mem
# lat                         71.2854
# lon                        -156.766
# alt                              44
# tz                               -9
# dst                               A
# tzone             America/Anchorage
# Name: 230, dtype: object

# %% [markdown]
# # The northernmost airport in is the Wiley Post Will Rogers Mem in Alaska.
# # The easternmost airport is appropriately named Eastport Municipal Airport in Maine.

# %% [markdown]
# # Now it's time to find the windiest NY airport on February 12, 2013
#
# ### Lets see what years are in the data

# %%
weather.year.value_counts()
# Out:
# 2013    26130
# Name: year, dtype: int64

# %% [markdown]
# ### Great! I don't need to filter by year since all entries are from 2013. Now I'll choose only the data from February 12

# %%
weather = weather[(weather.month == 2) & (weather.day == 12)]
weather.origin.value_counts()
# Out:
# JFK    24
# EWR    24
# LGA    24
# Name: origin, dtype: int64

# %% [markdown]
# ### Using groupby will let me get the calculations for each airport for that day.

# %%
weather.groupby('origin').wind_speed.agg(['count','min','max','mean','std'])
# Out:
#         count      min         max       mean         std
# origin
# EWR        24  0.00000  1048.36058  55.668983  211.507035
# JFK        24  0.00000    20.71404  13.090123    6.011440
# LGA        24  3.45234    23.01560  13.857309    5.703436

# %% [markdown]
# ### OK, something's not right here. The numbers for Newark would mean they were hit with a tornado. Let's take a look at only Newark's weather:

# %%
weather[weather.origin=='EWR']
# Out:
#      origin  year  month  day  hour   temp   dewp   humid  wind_dir  \
# 1007    EWR  2013      2   12     0  42.98  42.98  100.00       0.0
# 1008    EWR  2013      2   12     1  42.08  42.08  100.00     300.0
# 1009    EWR  2013      2   12     2  42.80  42.80  100.00     310.0
# 1010    EWR  2013      2   12     3  42.80  42.80  100.00     280.0
# 1011    EWR  2013      2   12     4  44.60  42.80   93.35     290.0
# 1012    EWR  2013      2   12     5  39.92  39.02   96.55     240.0
# 1013    EWR  2013      2   12     6  39.92  37.94   92.56     250.0
# 1014    EWR  2013      2   12     7  39.92  28.04   62.21     270.0
# 1015    EWR  2013      2   12     8  39.02  26.96   61.63     260.0
# 1016    EWR  2013      2   12     9  39.02  26.96   61.63     260.0
# 1017    EWR  2013      2   12    10  39.20  26.60   60.29     270.0
# 1018    EWR  2013      2   12    11  39.02  26.96   61.63     270.0
# 1019    EWR  2013      2   12    12  39.92  24.98   54.81     260.0
# 1020    EWR  2013      2   12    13  39.20  26.60   60.29     240.0
# 1021    EWR  2013      2   12    14  41.90  24.98   50.77     290.0
# 1022    EWR  2013      2   12    15  42.08  26.06   52.73     260.0
# 1023    EWR  2013      2   12    16  42.98  24.98   48.70     260.0
# 1024    EWR  2013      2   12    17  44.06  26.06   48.87     270.0
# 1025    EWR  2013      2   12    18  46.04  26.06   45.33     280.0
# 1026    EWR  2013      2   12    19  44.96  26.06   47.23     280.0
